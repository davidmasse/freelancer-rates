# %% [markdown]
# ## Freelancer hourly rates (upwork.com) are a function of skills, work experience and words used in profile headiline and bio (and possibly country)

# %% [markdown]
# ## Target (hourly rates) as well as predictors are "Poisson" distributed:

# %% [markdown]
# ![Screen%20Shot%202018-09-25%20at%2012.56.50%20PM.png](attachment:Screen%20Shot%202018-09-25%20at%2012.56.50%20PM.png)
# ![Screen%20Shot%202018-09-25%20at%2012.57.40%20PM.png](attachment:Screen%20Shot%202018-09-25%20at%2012.57.40%20PM.png)
# ![Screen%20Shot%202018-09-25%20at%2012.58.52%20PM.png](attachment:Screen%20Shot%202018-09-25%20at%2012.58.52%20PM.png)
# ![Screen%20Shot%202018-09-25%20at%2012.59.41%20PM.png](attachment:Screen%20Shot%202018-09-25%20at%2012.59.41%20PM.png)

# %% [markdown]
# ## Regression on numeric predictors provides a statistically significant but loose model of hourly rates

# %% [markdown]
# ## Each freelancer can choose up to 10 out of 1500+ skills to list.  To avoid the curse of dimensionality, we use a form of PCA for categorical data caled multiple correspondence analysis

# %% [markdown]
# ## We can also use NLP on the 'headline' and 'bio' free-text portions of frelancers' profiles to the most important words used in profile with a high hourly rate

# %% [markdown]
# ## Do PCA on document word-count vectors (topic modeling)

# %% [markdown]
# numeric features:
# number of skills,
# hours worked,
# jobs done,
# number of tests
#
# categorical feature:
# skills cluster,
# skills,
# country,
# city,
# state
#
# text:
# headline,
# bio

# %% [markdown]
# ## kmodes clustering?  ordinal regression (Python package "mord")?   regression version of classification models (start with KNN)?

# %% [markdown]
# ## partial dependence plots

# %% [markdown]
# ## box and whiskers plot clusters
